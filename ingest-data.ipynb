# %%
from sqlalchemy import create_engine
import pandas as pd
import json
import numpy as np

# %%
# read the json file to python dict
def get_postgres_credentials(path='config.json'):
    with open(path, 'r') as file:
        config = json.load(file)
    return config['postgres']

# connect to postgres using create_engine
def connect_to_postgres():
    credentials = get_postgres_credentials()
    connection_string = (
        f"postgresql://{credentials['user']}:{credentials['password']}@{credentials['host']}:{credentials['port']}/{credentials['database']}"
    )
    engine = create_engine(connection_string)
    connection = engine.connect()
    return connection

# %%
df = pd.read_csv('Datasets/tickets.csv')

# %%
df.head()
# Out:
#   Created Date    Ticket No.            Category        Sub-Category  \
# 0   2023-01-05  #INC-5497977      ITD HQ Support     Network Concern
# 1   2023-01-05  #INC-5498082      ITD HQ Support           DPC Email
# 2   2023-01-09  #INC-5523025      ITD HQ Support     Network Concern
# 3   2023-01-09  #INC-5509790      ITD HQ Support  PC/Printer Concern
# 4   2023-01-09  #INC-5526435  HQ/District Office  PC/Printer Concern
#
#                                              Subject    Status  Department  \
# 0                    Network Connection Installation  Resolved         ITD
# 1                Transferring of Thunderbird Account  Resolved     FINANCE
# 2                      Network Connection Assistance  Resolved         NaN
# 3               Installation of Autocad and Sketchup  Resolved         DNC
# 4  Wifi connection and printer connection in Visa...  Resolved  OPERATIONS
#
#   Urgency Date Resolved Isolation
# 0     NaN    2023-01-05       NaN
# 1     NaN    2023-01-05       NaN
# 2     NaN    2023-01-09       NaN
# 3     NaN    2023-01-11       NaN
# 4     NaN    2023-01-10       NaN

# %%
df.drop(columns=['Category'], inplace=True)

# %%
df.rename(columns={"Created Date":"created_date", "Ticket No.": "ticket_id","Sub-Category": "category_name", "Isolation": "remarks", "Date Resolved": "resolved_date", "Department": "department_name"}, inplace=True)

# %%
df['ticket_id'] = df['ticket_id'].str.strip('#INC-')

# %%
df['Urgency'] = df['Urgency'].apply(lambda x: np.random.choice(['Urgent', 'High', 'Medium', 'Low']) if pd.isnull(x) else x)

# %%
df[df['ticket_id'].duplicated() == True]
# Out:
# Empty DataFrame
# Columns: [created_date, ticket_id, category_name, Subject, Status, department_name, Urgency, resolved_date, remarks]
# Index: []

# %%
df['ticket_id'] = df['ticket_id'].astype('int')
df['created_date'] = pd.to_datetime(df['created_date'])
df['resolved_date'] = pd.to_datetime(df['resolved_date'])

# %%
df['Urgency'] = df['Urgency'].apply(lambda x: np.random.choice(['Urgent', 'High', 'Medium', 'Low']) if pd.isnull(x) else x)

# %%
unique_dept = df['department_name'].dropna().unique()
df['department_name'] = df['department_name'].fillna(pd.Series(np.random.choice(unique_dept, size=len(df.index))))

# %%
df
# Out:
#     created_date  ticket_id              category_name  \
# 0     2023-01-05    5497977            Network Concern
# 1     2023-01-05    5498082                  DPC Email
# 2     2023-01-09    5523025            Network Concern
# 3     2023-01-09    5509790         PC/Printer Concern
# 4     2023-01-09    5526435         PC/Printer Concern
# ..           ...        ...                        ...
# 438   2024-02-15    7035163              Email Concern
# 439   2024-02-15    7037058  Software/App Installation
# 440   2024-02-16    7039343  DPC Module Remote Desktop
# 441   2024-02-16    7039580  DPC Module Remote Desktop
# 442   2024-02-16    7039551  DPC Module Remote Desktop
#
#                                                Subject    Status  \
# 0                      Network Connection Installation  Resolved
# 1                  Transferring of Thunderbird Account  Resolved
# 2                        Network Connection Assistance  Resolved
# 3                 Installation of Autocad and Sketchup  Resolved
# 4    Wifi connection and printer connection in Visa...  Resolved
# ..                                                 ...       ...
# 438                                    Forgot password      Open
# 439                Excel Problem - file can't be saved  Resolved
# 440            DPC Remote Desktop - Bacolod 02/16/2024  Resolved
# 441  Unable to access remote module IP 192.168.20.1...  Resolved
# 442      Unable to access remote module 192.168.20.143  Resolved
#
#     department_name Urgency resolved_date  \
# 0               ITD  Medium    2023-01-05
# 1           FINANCE  Urgent    2023-01-05
# 2               NaN  Urgent    2023-01-09
# 3               DNC  Medium    2023-01-11
# 4        OPERATIONS  Medium    2023-01-10
# ..              ...     ...           ...
# 438             BDD  Medium           NaT
# 439           LEGAL     Low    2024-02-15
# 440         FINANCE     Low    2024-02-16
# 441         FINANCE     Low    2024-02-16
# 442         FINANCE     Low    2024-02-16
#
#                                           remarks
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# ..                                            ...
# 438                                           NaN
# 439                     File save in autorecovery
# 440  coordinate to HQ group to restart the module
# 441  coordinate to HQ group to restart the module
# 442  coordinate to HQ group to restart the module
#
# [443 rows x 9 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 443 entries, 0 to 442
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   created_date     443 non-null    datetime64[ns]
#  1   ticket_id        443 non-null    int32
#  2   category_name    443 non-null    object
#  3   Subject          443 non-null    object
#  4   Status           443 non-null    object
#  5   department_name  379 non-null    object
#  6   Urgency          67 non-null     object
#  7   resolved_date    439 non-null    datetime64[ns]
#  8   remarks          271 non-null    object
# dtypes: datetime64[ns](2), int32(1), object(6)
# memory usage: 29.5+ KB

# %%
df = df.drop_duplicates()

# %%
df
# Out:
#     created_date  ticket_id              category_name  \
# 0     2023-01-05    5497977            Network Concern
# 1     2023-01-05    5498082                  DPC Email
# 2     2023-01-09    5523025            Network Concern
# 3     2023-01-09    5509790         PC/Printer Concern
# 4     2023-01-09    5526435         PC/Printer Concern
# ..           ...        ...                        ...
# 438   2024-02-15    7035163              Email Concern
# 439   2024-02-15    7037058  Software/App Installation
# 440   2024-02-16    7039343  DPC Module Remote Desktop
# 441   2024-02-16    7039580  DPC Module Remote Desktop
# 442   2024-02-16    7039551  DPC Module Remote Desktop
#
#                                                Subject    Status  \
# 0                      Network Connection Installation  Resolved
# 1                  Transferring of Thunderbird Account  Resolved
# 2                        Network Connection Assistance  Resolved
# 3                 Installation of Autocad and Sketchup  Resolved
# 4    Wifi connection and printer connection in Visa...  Resolved
# ..                                                 ...       ...
# 438                                    Forgot password      Open
# 439                Excel Problem - file can't be saved  Resolved
# 440            DPC Remote Desktop - Bacolod 02/16/2024  Resolved
# 441  Unable to access remote module IP 192.168.20.1...  Resolved
# 442      Unable to access remote module 192.168.20.143  Resolved
#
#     department_name Urgency resolved_date  \
# 0               ITD     NaN    2023-01-05
# 1           FINANCE     NaN    2023-01-05
# 2               NaN     NaN    2023-01-09
# 3               DNC     NaN    2023-01-11
# 4        OPERATIONS     NaN    2023-01-10
# ..              ...     ...           ...
# 438             BDD  Medium           NaT
# 439           LEGAL     Low    2024-02-15
# 440         FINANCE     Low    2024-02-16
# 441         FINANCE     Low    2024-02-16
# 442         FINANCE     Low    2024-02-16
#
#                                           remarks
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# ..                                            ...
# 438                                           NaN
# 439                     File save in autorecovery
# 440  coordinate to HQ group to restart the module
# 441  coordinate to HQ group to restart the module
# 442  coordinate to HQ group to restart the module
#
# [443 rows x 9 columns]

# %%
engine = connect_to_postgres()

# %%
df.to_sql(name="tickets_temp", con=engine, if_exists="replace", index=False)
# Out:
# 443

# %%
print(pd.io.sql.get_schema(df, name="tickets_temp"))
# Out:
# CREATE TABLE "tickets_temp" (
# "created_date" TIMESTAMP,
#   "ticket_id" INTEGER,
#   "category_name" TEXT,
#   "Subject" TEXT,
#   "Status" TEXT,
#   "department_name" TEXT,
#   "Urgency" TEXT,
#   "resolved_date" TIMESTAMP,
#   "remarks" TEXT
# )
